# %% [markdown]
# ## Практика по PyTorch

# %% [markdown]
# Создать и обучить регрессионную модель, которая аппроксимирует значение функции sin(x + 2*y)exp(-(2x + y)^2) на диапазоне значений [-10;10] по х и у.

# %% [markdown]
# ### Окружение

# %%
# %pip install -q numpy pandas matplotlib seaborn torch
# Out:
# [notice] A new release of pip is available: 25.0 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
device = torch.device("cpu")
if torch.cuda.is_available():
    device = torch.device("cuda:0")
elif torch.backends.mps.is_available():
     device = torch.device("mps:0")

# %% [markdown]
# ### Задаём целевую функцию

# %%
def target_function(x, y):
    """sin(x + 2*y) * exp(-(2*x + y)^2)"""
    return torch.sin(x + 2*y) * torch.exp(-(2*x + y)**2)

# %% [markdown]
# И диапазон моделирования:

# %%
torch.manual_seed(42)
x = torch.empty(20000, device=device).uniform_(-10, 10)
y = torch.empty(20000, device=device).uniform_(-10, 10)

# %%
z = target_function(x, y)

# %% [markdown]
# ### Создаём датасет и делим его на тренировочный, валидационный и тестовый

# %%
from torch.utils.data import TensorDataset, random_split

xy = torch.column_stack([x, y])
z = z.view(-1, 1)

dataset = TensorDataset(xy, z)
train_data, val_data, test_data = random_split(
    dataset, [0.7, 0.15, 0.15]
)

X_train = train_data.dataset.tensors[0][train_data.indices]
z_train = train_data.dataset.tensors[1][train_data.indices]

X_val = val_data.dataset.tensors[0][val_data.indices]
z_val = val_data.dataset.tensors[1][val_data.indices]

X_test = test_data.dataset.tensors[0][test_data.indices]
z_test = test_data.dataset.tensors[1][test_data.indices]

# %% [markdown]
# ### Создаём модель

# %%
class RegressionNet(nn.Module):
    def __init__(self, n_hidden_neurons):
        super().__init__()
        self.fc1 = nn.Linear(2, n_hidden_neurons)
        self.act1 = nn.Tanh()
        self.fc2 = nn.Linear(n_hidden_neurons, n_hidden_neurons)
        self.act2 = nn.Tanh()
        self.fc3 = nn.Linear(n_hidden_neurons, 1)

    def forward(self, x):
        x = self.act1(self.fc1(x))
        x = self.act2(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
torch.manual_seed(42)
model = RegressionNet(128).to(device)

# %% [markdown]
# И обучаем её:

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
n_epochs = 8000
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=n_epochs)

# %%
train_losses = []
val_losses = []

for epoch in range(n_epochs):
    model.train()
    optimizer.zero_grad()
    pred_train = model(X_train)
    loss_train = criterion(pred_train, z_train)
    loss_train.backward()
    optimizer.step()
    scheduler.step()

    model.eval()
    with torch.no_grad():
        pred_val = model(X_val)
        loss_val = criterion(pred_val, z_val)

    train_losses.append(loss_train.item())
    val_losses.append(loss_val.item())

    if (epoch + 1) % 100 == 0:
        print(f"Epoch {epoch+1:4d} | Train Loss: {loss_train.item():.6f} | Val Loss: {loss_val.item():.6f} | LR: {optimizer.param_groups[0]['lr']:.6f}")
# Out:
# Epoch  100 | Train Loss: 0.015287 | Val Loss: 0.012262 | LR: 0.001000
# Epoch  200 | Train Loss: 0.014980 | Val Loss: 0.011912 | LR: 0.000998
# Epoch  300 | Train Loss: 0.014712 | Val Loss: 0.011598 | LR: 0.000997
# Epoch  400 | Train Loss: 0.014475 | Val Loss: 0.011309 | LR: 0.000994
# Epoch  500 | Train Loss: 0.014228 | Val Loss: 0.011016 | LR: 0.000990
# Epoch  600 | Train Loss: 0.013948 | Val Loss: 0.010688 | LR: 0.000986
# Epoch  700 | Train Loss: 0.013520 | Val Loss: 0.010158 | LR: 0.000981
# Epoch  800 | Train Loss: 0.013104 | Val Loss: 0.009648 | LR: 0.000976
# Epoch  900 | Train Loss: 0.012713 | Val Loss: 0.009165 | LR: 0.000969
# Epoch 1000 | Train Loss: 0.012384 | Val Loss: 0.008771 | LR: 0.000962
# Epoch 1100 | Train Loss: 0.012079 | Val Loss: 0.008422 | LR: 0.000954
# Epoch 1200 | Train Loss: 0.011816 | Val Loss: 0.008140 | LR: 0.000946
# Epoch 1300 | Train Loss: 0.011571 | Val Loss: 0.007900 | LR: 0.000936
# Epoch 1400 | Train Loss: 0.011375 | Val Loss: 0.007720 | LR: 0.000926
# Epoch 1500 | Train Loss: 0.011155 | Val Loss: 0.007498 | LR: 0.000916
# Epoch 1600 | Train Loss: 0.010981 | Val Loss: 0.007307 | LR: 0.000905
# Epoch 1700 | Train Loss: 0.010768 | Val Loss: 0.007119 | LR: 0.000893
# Epoch 1800 | Train Loss: 0.010549 | Val Loss: 0.006917 | LR: 0.000880
# Epoch 1900 | Train Loss: 0.010302 | Val Loss: 0.006722 | LR: 0.000867
# Epoch 2000 | Train Loss: 0.010007 | Val Loss: 0.006518 | LR: 0.000854
# Epoch 2100 | Train Loss: 0.009847 | Val Loss: 0.006303 | LR: 0.000839
# Epoch 2200 | Train Loss: 0.009409 | Val Loss: 0.006062 | LR: 0.000825
# Epoch 2300 | Train Loss: 0.009078 | Val Loss: 0.005825 | LR: 0.000810
# Epoch 2400 | Train Loss: 0.008777 | Val Loss: 0.005612 | LR: 0.000794
# Epoch 2500 | Train Loss: 0.008459 | Val Loss: 0.005392 | LR: 0.000778
# Epoch 2600 | Train Loss: 0.008153 | Val Loss: 0.005235 | LR: 0.000761
# Epoch 2700 | Train Loss: 0.007768 | Val Loss: 0.004920 | LR: 0.000744
# Epoch 2800 | Train Loss: 0.007438 | Val Loss: 0.004704 | LR: 0.000727
# Epoch 2900 | Train Loss: 0.007100 | Val Loss: 0.004491 | LR: 0.000709
# Epoch 3000 | Train Loss: 0.006792 | Val Loss: 0.004303 | LR: 0.000691
# Epoch 3100 | Train Loss: 0.006476 | Val Loss: 0.004118 | LR: 0.000673
# Epoch 3200 | Train Loss: 0.006163 | Val Loss: 0.003940 | LR: 0.000655
# Epoch 3300 | Train Loss: 0.005869 | Val Loss: 0.003777 | LR: 0.000636
# Epoch 3400 | Train Loss: 0.005593 | Val Loss: 0.003625 | LR: 0.000617
# Epoch 3500 | Train Loss: 0.005325 | Val Loss: 0.003470 | LR: 0.000598
# Epoch 3600 | Train Loss: 0.005077 | Val Loss: 0.003328 | LR: 0.000578
# Epoch 3700 | Train Loss: 0.004835 | Val Loss: 0.003192 | LR: 0.000559
# Epoch 3800 | Train Loss: 0.004609 | Val Loss: 0.003066 | LR: 0.000539
# Epoch 3900 | Train Loss: 0.004399 | Val Loss: 0.002997 | LR: 0.000520
# Epoch 4000 | Train Loss: 0.004186 | Val Loss: 0.002824 | LR: 0.000500
# Epoch 4100 | Train Loss: 0.004501 | Val Loss: 0.003180 | LR: 0.000480
# Epoch 4200 | Train Loss: 0.003809 | Val Loss: 0.002616 | LR: 0.000461
# Epoch 4300 | Train Loss: 0.003636 | Val Loss: 0.002522 | LR: 0.000441
# Epoch 4400 | Train Loss: 0.003470 | Val Loss: 0.002432 | LR: 0.000422
# Epoch 4500 | Train Loss: 0.003316 | Val Loss: 0.002349 | LR: 0.000402
# Epoch 4600 | Train Loss: 0.003174 | Val Loss: 0.002276 | LR: 0.000383
# Epoch 4700 | Train Loss: 0.003041 | Val Loss: 0.002207 | LR: 0.000364
# Epoch 4800 | Train Loss: 0.002919 | Val Loss: 0.002143 | LR: 0.000345
# Epoch 4900 | Train Loss: 0.002807 | Val Loss: 0.002085 | LR: 0.000327
# Epoch 5000 | Train Loss: 0.002702 | Val Loss: 0.002030 | LR: 0.000309
# Epoch 5100 | Train Loss: 0.002604 | Val Loss: 0.001977 | LR: 0.000291
# Epoch 5200 | Train Loss: 0.002512 | Val Loss: 0.001926 | LR: 0.000273
# Epoch 5300 | Train Loss: 0.002427 | Val Loss: 0.001878 | LR: 0.000256
# Epoch 5400 | Train Loss: 0.002347 | Val Loss: 0.001832 | LR: 0.000239
# Epoch 5500 | Train Loss: 0.002272 | Val Loss: 0.001787 | LR: 0.000222
# Epoch 5600 | Train Loss: 0.002202 | Val Loss: 0.001745 | LR: 0.000206
# Epoch 5700 | Train Loss: 0.002138 | Val Loss: 0.001704 | LR: 0.000190
# Epoch 5800 | Train Loss: 0.002078 | Val Loss: 0.001666 | LR: 0.000175
# Epoch 5900 | Train Loss: 0.002023 | Val Loss: 0.001630 | LR: 0.000161
# Epoch 6000 | Train Loss: 0.001972 | Val Loss: 0.001596 | LR: 0.000146
# Epoch 6100 | Train Loss: 0.001926 | Val Loss: 0.001565 | LR: 0.000133
# Epoch 6200 | Train Loss: 0.001884 | Val Loss: 0.001536 | LR: 0.000120
# Epoch 6300 | Train Loss: 0.001845 | Val Loss: 0.001509 | LR: 0.000107
# Epoch 6400 | Train Loss: 0.001811 | Val Loss: 0.001485 | LR: 0.000095
# Epoch 6500 | Train Loss: 0.001780 | Val Loss: 0.001463 | LR: 0.000084
# Epoch 6600 | Train Loss: 0.001752 | Val Loss: 0.001443 | LR: 0.000074
# Epoch 6700 | Train Loss: 0.001728 | Val Loss: 0.001426 | LR: 0.000064
# Epoch 6800 | Train Loss: 0.001706 | Val Loss: 0.001410 | LR: 0.000054
# Epoch 6900 | Train Loss: 0.001688 | Val Loss: 0.001397 | LR: 0.000046
# Epoch 7000 | Train Loss: 0.001672 | Val Loss: 0.001385 | LR: 0.000038
# Epoch 7100 | Train Loss: 0.001659 | Val Loss: 0.001375 | LR: 0.000031
# Epoch 7200 | Train Loss: 0.001648 | Val Loss: 0.001367 | LR: 0.000024
# Epoch 7300 | Train Loss: 0.001639 | Val Loss: 0.001361 | LR: 0.000019
# Epoch 7400 | Train Loss: 0.001632 | Val Loss: 0.001356 | LR: 0.000014
# Epoch 7500 | Train Loss: 0.001627 | Val Loss: 0.001352 | LR: 0.000010
# Epoch 7600 | Train Loss: 0.001624 | Val Loss: 0.001349 | LR: 0.000006
# Epoch 7700 | Train Loss: 0.001621 | Val Loss: 0.001348 | LR: 0.000003
# Epoch 7800 | Train Loss: 0.001620 | Val Loss: 0.001347 | LR: 0.000002
# Epoch 7900 | Train Loss: 0.001620 | Val Loss: 0.001346 | LR: 0.000000
# Epoch 8000 | Train Loss: 0.001620 | Val Loss: 0.001346 | LR: 0.000000

# %% [markdown]
# ### Оцениваем качество модели
#
# Для ориентира возьмём модель, предсказывающую всегда нули:

# %%
print("Baseline MSE: ", criterion(torch.zeros_like(z_val), z_val).item())
# Out:
# Baseline MSE:  0.012541739270091057

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.eval()
with torch.no_grad():
    pred_test = model(X_test)
    loss_test = criterion(pred_test, z_test)

print(f"Baseline MSE: {criterion(torch.zeros_like(z_val), z_val).item():.6f}")
print(f"Test MSE: {loss_test.item():.6f}")
# Out:
# Baseline MSE: 0.012542
# Test MSE: 0.001768

# %%
grid_size = 50
x_grid = torch.linspace(-10, 10, grid_size, device=device)
y_grid = torch.linspace(-10, 10, grid_size, device=device)
X_grid, Y_grid = torch.meshgrid(x_grid, y_grid, indexing='ij')

# Истинные значения
Z_true = target_function(X_grid, Y_grid).cpu().numpy()

# Предсказания модели
grid_tensor = torch.column_stack([X_grid.ravel(), Y_grid.ravel()])

model.eval()
with torch.no_grad():
    Z_pred = model(grid_tensor).cpu().numpy().reshape(grid_size, grid_size)

X_np = X_grid.cpu().numpy()
Y_np = Y_grid.cpu().numpy()

fig = plt.figure(figsize=(14, 5))

ax1 = fig.add_subplot(1, 2, 1, projection='3d')
surf1 = ax1.plot_surface(X_np, Y_np, Z_true, cmap='viridis', alpha=0.8)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
ax1.set_title('Истинная функция')
plt.colorbar(surf1, ax=ax1, shrink=0.5)

ax2 = fig.add_subplot(1, 2, 2, projection='3d')
surf2 = ax2.plot_surface(X_np, Y_np, Z_pred, cmap='viridis', alpha=0.8)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
ax2.set_title('Предсказанная функция')
plt.colorbar(surf2, ax=ax2, shrink=0.5)

plt.tight_layout()
plt.show()

# %%
x_line = torch.linspace(-10, 10, 1000, device=device)
y_fixed = torch.zeros(1000, device=device)

z_true_line = target_function(x_line, y_fixed).cpu().numpy()

model.eval()
with torch.no_grad():
    z_pred_line = model(torch.column_stack([x_line, y_fixed])).cpu().numpy().flatten()

plt.figure(figsize=(12, 4))
plt.plot(x_line.cpu().numpy(), z_true_line, label='Истинная функция', linewidth=2)
plt.plot(x_line.cpu().numpy(), z_pred_line, label='Предсказание', linewidth=2, linestyle='--')
plt.xlabel('x')
plt.ylabel('z')
plt.title('Сравнение при y=0')
plt.legend()
plt.grid(True)
plt.show()
